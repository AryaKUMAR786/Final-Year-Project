# %%
import pandas as pd

# %%
# Using a different encoding based on the detection
df = pd.read_csv('Indian_startup_funding.csv', encoding='ISO-8859-1')

# %%
df
# Out:
#       S.No Date dd/mm/yyyy      Startup Name    Industry Vertical  \
# 0        1        9/1/2020            BYJUS               E-Tech
# 1        2      13-01-2020            Shuttl       Transportation
# 2        3        9/1/2020         Mamaearth           E-commerce
# 3        4        2/1/2020      wealthbucket              FinTech
# 4        5        2/1/2020            Fashor  Fashion and Apparel
# ...    ...             ...               ...                  ...
# 3039  3040      29-01-2015        Printvenue                  NaN
# 3040  3041      29-01-2015          Graphene                  NaN
# 3041  3042      30-01-2015    Mad Street Den                  NaN
# 3042  3043      30-01-2015         Simplotel                  NaN
# 3043  3044      31-01-2015  couponmachine.in                  NaN
#
#                                Sub Vertical City  Location  \
# 0                                E-learning      Bengaluru
# ...

# %%
df.columns
# Out:
# Index(['S.No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'Sub Vertical', 'City  Location', 'Investors Name', 'Investment Type',
#        'Amount in USD', 'Remarks'],
#       dtype='object')

# %%
df = df.drop(columns=['S.No','Date dd/mm/yyyy','Startup Name','Remarks'])

# %%
df.to_csv('data.csv', index=False)
